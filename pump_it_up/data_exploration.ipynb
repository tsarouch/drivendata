# %% [markdown]
# # Imports

# %%
import sys
sys.path.append('/Users/charilaostsarouchas/tsarouch_github/drivendata/pump_it_up')
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from reader import get_train_data_df, get_test_data_df

# %% [markdown]
# # Readers

# %%
df_train = get_train_data_df()

# %% [markdown]
# # Statistics

# %%
print "The train data sample includes the features: ", df_train.columns
print "The train data sample has N features: ", len(df_train.columns)
print "The train data sample has ", len(df_train),  " rows"
print "If we remove all NaNs form rows we end up with length", len(df_train.dropna())
print "The train data exaple: "
df_train.head(3)
# Out:
# The train data sample includes the features:  Index([u'id', u'amount_tsh', u'date_recorded', u'funder', u'gps_height',
#        u'installer', u'longitude', u'latitude', u'wpt_name', u'num_private',
#        u'basin', u'subvillage', u'region', u'region_code', u'district_code',
#        u'lga', u'ward', u'population', u'public_meeting', u'recorded_by',
#        u'scheme_management', u'scheme_name', u'permit', u'construction_year',
#        u'extraction_type', u'extraction_type_group', u'extraction_type_class',
#        u'management', u'management_group', u'payment', u'payment_type',
#        u'water_quality', u'quality_group', u'quantity', u'quantity_group',
#        u'source', u'source_type', u'source_class', u'waterpoint_type',
#        u'waterpoint_type_group', u'status_group'],
#       dtype='object')
# The train data sample has N features:  41
# The train data sample has  59400  rows
# If we remove all NaNs form rows we end up with length 27813
# The train data exaple:
# ...

# %%
import seaborn as sns
sns.set()
sns.pairplot(df_train, hue="status_group")

# %%
plt.show()
